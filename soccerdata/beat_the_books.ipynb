# %% [markdown]
# # Introduction

# %%
import soccerdata as sd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

TEST_PRINT = False
def test_print(x):
    if TEST_PRINT:
        if isinstance(x, pd.DataFrame):
            print(x.head())
        elif isinstance(x, pd.Series):
            print(x.head())
        elif isinstance(x, np.ndarray):
            print(x[:5])
        elif isinstance(x, list):
            print(x[:5])
        else:
            print(x)
# Out:
# [06/28/25 22:24:11] INFO     No custom team name replacements found. You can configure these in       ]8;id=415506;file://c:\Users\Aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=431774;file://c:\Users\Aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\_config.py#90\90]8;;\
#                              C:\Users\Aaron\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=321991;file://c:\Users\Aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=146346;file://c:\Users\Aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\_config.py#196\196]8;;\
#                              C:\Users\Aaron\soccerdata\config\league_dict.json.

# %% [markdown]
# # Import Data

# %%
# Create scraper class instance
fbref = sd.FBref(seasons=[2425], leagues=['GER-Bundesliga'])
# Out:
# [06/28/25 22:24:17] INFO     Saving cached data to C:\Users\Aaron\soccerdata\data\FBref              ]8;id=565524;file://c:\Users\Aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=875989;file://c:\Users\Aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\_common.py#263\263]8;;\

# %%
team_stats = fbref.read_team_season_stats()
player_stats = fbref.read_player_season_stats(stat_type='standard')
player_stats
# Out:
# c:\Users\Aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\fbref.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(dfs)
# c:\Users\Aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\fbref.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(dfs)
#                                                       nation    pos age  born  \
#
# league         season team      player
# ...

# %%
player_match_stats = fbref.read_player_match_stats(stat_type='summary')
player_match_stats
# Out:
# c:\Users\Aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\fbref.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(dfs)
# [06/28/25 22:24:20] INFO     [1/308] Retrieving game with id=d42e53df                                  ]8;id=148425;file://c:\Users\Aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\fbref.py\fbref.py]8;;\:]8;id=940605;file://c:\Users\Aaron\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\fbref.py#816\816]8;;\
# ...

# %%
import csv
# go get data from a csv file saved a folder backwards
with open('../D1.csv', 'r') as f:
    reader = csv.reader(f)
    live_odds = list(reader)
# convert to dataframe
live_odds = pd.DataFrame(live_odds[1:], columns=live_odds[0])
live_odds
# Out:
#     ï»¿Div        Date   Time    HomeTeam       AwayTeam FTHG FTAG FTR HTHG  \
# 0       D1  23/08/2024  19:30  M'gladbach     Leverkusen    2    3   A    0
# 1       D1  24/08/2024  14:30    Augsburg  Werder Bremen    2    2   D    2
# 2       D1  24/08/2024  14:30    Freiburg      Stuttgart    3    1   H    1
# 3       D1  24/08/2024  14:30  Hoffenheim  Holstein Kiel    3    2   H    2
# 4       D1  24/08/2024  14:30       Mainz   Union Berlin    1    1   D    0
# ..     ...         ...    ...         ...            ...  ...  ...  ..  ...
# 301     D1  17/05/2025  14:30  Hoffenheim  Bayern Munich    0    4   A    0
# 302     D1  17/05/2025  14:30       Mainz     Leverkusen    2    2   D    1
# 303     D1  17/05/2025  14:30  M'gladbach      Wolfsburg    0    1   A    0
# 304     D1  17/05/2025  14:30  RB Leipzig      Stuttgart    2    3   A    2
# 305     D1  17/05/2025  14:30    St Pauli         Bochum    0    2   A    0
#
# ...

# %%
# Lastly, were going to get player transfer value data

# %% [markdown]
# # Paramter Generation by Manipulating the way Data is Stored

# %%
game_logs_by_player = dict()
# player_match_stats = player_match_stats.reset_index()
# player_match_stats.columns.values[:5] = ['league', 'player_id', 'match_info', 'team', 'player_name']

for _, match in player_match_stats.iterrows():
    # print(match)
    # print(match.keys())
    player_name = match['player'].item()
    print(player_name)
    if player_name not in game_logs_by_player.keys():
        game_logs_by_player[player_name] = []
    game_logs_by_player[player_name].append(match)

game_logs_by_player["Harry Kane"]
# Out:
# Aleix García
# Amine Adli
# Edmond Tapsoba
# Florian Wirtz
# Granit Xhaka
# Jeremie Frimpong
# Jonas Hofmann
# Jonathan Tah
# Lukáš Hrádecký
# Martin Terrier
# Piero Hincapié
# Robert Andrich
# Victor Boniface
# Álex Grimaldo
# Alassane Pléa
# Fabio Chiarodia
# Franck Honorat
# Joe Scally
# Jonas Omlin
# Julian Weigl
# Kevin Stöger
# Ko Itakura
# Luca Netz
# Nathan N'Goumou
# Nico Elvedi
# Philipp Sander
# Rocco Reitz
# Stefan Lainer
# Tim Kleindienst
# Tomáš Čvančara
# Arne Engels
# Arne Maier
# Dimitris Giannoulis
# Elvis Rexhbeçaj
# Fredrik Jensen
# Jeffrey Gouweleeuw
# Keven Schlotterbeck
# Mads Pedersen
# Marius Wolf
# Maximilian Bauer
# Nediljko Labrović
# Niklas Dorsch
# Phillip Tietz
# Samuel Essende
# Steve Mounié
# Tim Breithaupt
# Anthony Jung
# Felix Agu
# Jens Stage
# Justin Njinmah
# Keke Maximilian Topp
# Leonardo Bittencourt
# Marco Friedl
# Marco Grüll
# Marvin Ducksch
# Michael Zetterer
# Miloš Veljković
# Mitchell Weiser
# Niklas Stark
# Romano Schmid
# ...
